# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
cwd = '/content/drive/MyDrive/BookingcomChallenge2021/'

import os
os.chdir(cwd)
# Out:
# Mounted at /content/drive

# %%
import argparse
import time
import math
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.onnx
from torch.utils.tensorboard import SummaryWriter

import data
import model

# %%
parser = argparse.ArgumentParser(description='PyTorch RNN/LSTM/GRU/Transformer/LSTMTransformer Language Model')
parser.add_argument('--data', type=str, default='../data/wikitext-2',
                    help='location of the data corpus')
parser.add_argument('--model', type=str, default='LSTM',
                    help='type of recurrent net (RNN_TANH, RNN_RELU, LSTM, GRU, Transformer, LSTMTransformer)')
parser.add_argument('--emsize', type=int, default=200,
                    help='size of word embeddings')
parser.add_argument('--nhid', type=int, default=200,
                    help='number of hidden units per layer')
parser.add_argument('--nlayers', type=int, default=2,
                    help='number of layers')
parser.add_argument('--warm-up', type=int, default=4000,
                    help='number of steps to warm up')
parser.add_argument('--step-size', type=int, default=1,
                    help='period of learning rate decay')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
parser.add_argument('--epochs', type=int, default=40,
                    help='upper epoch limit')
parser.add_argument('--batch_size', type=int, default=20, metavar='N',
                    help='batch size')
parser.add_argument('--bptt', type=int, default=35,
                    help='sequence length')
parser.add_argument('--dropout', type=float, default=0.2,
                    help='dropout applied to layers (0 = no dropout)')
parser.add_argument('--tied', action='store_true',
                    help='tie the word embedding and softmax weights')
parser.add_argument('--seed', type=int, default=1111,
                    help='random seed')
parser.add_argument('--cuda', action='store_true',
                    help='use CUDA')
parser.add_argument('--val-interval', type=int, default=5000, metavar='N',
                    help='validation interval')
parser.add_argument('--log-interval', type=int, default=200, metavar='N',
                    help='report interval')
parser.add_argument('--save', type=str, default='model.pt',
                    help='path to save the final model')
parser.add_argument('--tb-log', type=str, default='logs',
                    help='path to save tensorboard log')
parser.add_argument('--onnx-export', type=str, default='',
                    help='path to export the final model in onnx format')

parser.add_argument('--nhead', type=int, default=2,
                    help='the number of heads in the encoder/decoder of the transformer model')
# Out:
# _StoreAction(option_strings=['--nhead'], dest='nhead', nargs=None, const=None, default=2, type=<class 'int'>, choices=None, help='the number of heads in the encoder/decoder of the transformer model', metavar=None)

# %%
args = parser.parse_args(args=["--data", "../booking_com_data/legs_4legs/",\
                               "--model", "LSTMTransformer",\
                               "--emsize", "512",\
                               "--nhid", "1024",\
                               "--nlayers", "5",\
                               "--clip", "5.0",\
                               "--batch_size", "16", \
                               "--bptt", "4",\
                               "--dropout", "0.1",\
                               "--log-interval", "200", \
                               "--save", "../models/lstm_transformer.pth",\
                               "--nhead", "8",\
                               "--cuda"])

# %%
# Set the random seed manually for reproducibility.
torch.manual_seed(args.seed)
if torch.cuda.is_available():
    if not args.cuda:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")

device = torch.device("cuda" if args.cuda else "cpu")
device
# Out:
# device(type='cuda')

# %%
args.data
# Out:
# '../booking_com_data/legs_4legs/'

# %%
args.model

# %%
###############################################################################
# Load data
###############################################################################

corpus = data.Corpus(args.data)

# %%
# Starting from sequential data, batchify arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data

eval_batch_size = 10
train_data = batchify(corpus.train, args.batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)

# %%
###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
if args.model == 'LSTMTransformer':
    model = model.LSTMTransformerModel(ntokens, args.emsize, args.nhead, args.nhid, args.nlayers, args.dropout).to(device)
elif args.model == 'Transformer':
    model = model.TransformerModel(ntokens, args.emsize, args.nhead, args.nhid, args.nlayers, args.dropout).to(device)
else:
    model = model.RNNModel(args.model, ntokens, args.emsize, args.nhid, args.nlayers, args.dropout, args.tied).to(device)

class TransformerLR(torch.optim.lr_scheduler.LambdaLR):
    """Warmup linearly and then decay proportionally to the inverse square root of the step number.
    """
    def __init__(self, optimizer, d_model, warmup_steps=4000, step_size=1, last_epoch=-1):
        self.d_model = d_model
        self.warmup_steps = warmup_steps
        self.step_size = step_size
        super(TransformerLR, self).__init__(optimizer, self.lr_lambda, last_epoch=last_epoch)

    def lr_lambda(self, step):
        if step // self.step_size == 0:
            return 0
        return (self.d_model ** -0.5) * \
               min((step // self.step_size) ** -0.5, (step // self.step_size) * (self.warmup_steps ** -1.5))

optimizer = optim.Adam(model.parameters(), lr=1)
scheduler = TransformerLR(optimizer, args.emsize, warmup_steps=4000, step_size=args.step_size)
criterion = nn.NLLLoss()

writer = SummaryWriter(log_dir=args.tb_log)

# %%
###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Tensors, to detach them from their history."""

    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)


# get_batch subdivides the source data into chunks of length args.bptt.
# If source is equal to the example output of the batchify function, with
# a bptt-limit of 2, we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the batchify function. The chunks are along dimension 0, corresponding
# to the seq_len dimension in the LSTM.

def get_batch(source, i, seq_len):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data.to(device), target.to(device)


def evaluate(data_source, seq_len):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    if args.model == 'LSTMTransformer':
        inp = torch.empty(0, dtype=torch.int64).to(device)
        hidden = model.init_hidden(eval_batch_size)
        mems = None
    elif args.model == 'Transformer':
        inp = torch.empty(0, dtype=torch.int64).to(device)
    else:
        hidden = model.init_hidden(eval_batch_size)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, seq_len):
            data, targets = get_batch(data_source, i, seq_len)
            if args.model == 'LSTMTransformer':
                output, hidden, mems = model(data, hidden, mems)
                output = output.view(-1, ntokens)
                hidden = repackage_hidden(hidden)
                mems = [mem[-args.bptt + seq_len:] for mem in mems] if args.bptt != seq_len else None
            elif args.model == 'Transformer':
                inp = torch.cat([inp, data], 0)[-args.bptt:]
                output = model(inp)
                output = output[-data.size(0):].view(-1, ntokens)
            else:
                output, hidden = model(data, hidden)
                hidden = repackage_hidden(hidden)
            total_loss += len(data) * criterion(output, targets).item()
    model.train()
    return total_loss / (len(data_source) - 1)


iteration = 0
best_val_loss = None

def train():
    global iteration
    global best_val_loss
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    if args.model != 'Transformer':
        hidden = model.init_hidden(args.batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, args.bptt)):
        data, targets = get_batch(train_data, i, args.bptt)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        optimizer.zero_grad()
        if args.model == 'LSTMTransformer':
            hidden = repackage_hidden(hidden)
            output, hidden, _ = model(data, hidden)
            output = output.view(-1, ntokens)
        elif args.model == 'Transformer':
            output = model(data)
            output = output.view(-1, ntokens)
        else:
            hidden = repackage_hidden(hidden)
            output, hidden = model(data, hidden)
        loss = criterion(output, targets)
        loss.backward()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm_(model.parameters(), args.clip)
        optimizer.step()
        scheduler.step()

        total_loss += loss.item()

        writer.add_scalar('train/loss', loss.item(), iteration)
        writer.add_scalar('train/ppl', math.exp(loss.item()), iteration)
        writer.flush()

        if batch % args.log_interval == 0 and batch > 0:
            cur_loss = total_loss / args.log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.5f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // args.bptt, scheduler.get_lr()[0],
                elapsed * 1000 / args.log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

        if iteration % args.val_interval == 0 and iteration > 0:
            val_loss = evaluate(val_data, args.bptt)
            print('-' * 89)
            print('| end of iteration {} | valid loss {:5.2f} | '
                    'valid ppl {:8.2f}'.format(iteration, val_loss, math.exp(val_loss)))
            print('-' * 89)
            writer.add_scalar('val/loss', val_loss, iteration)
            writer.add_scalar('val/ppl', math.exp(val_loss), iteration)
            writer.flush()
            # Save the model if the validation loss is the best we've seen so far.
            if not best_val_loss or val_loss < best_val_loss:
                with open(args.save, 'wb') as f:
                    torch.save(model, f)
                best_val_loss = val_loss

        iteration += 1

def export_onnx(path, batch_size, seq_len):
    print('The model is also exported in ONNX format at {}'.
          format(os.path.realpath(args.onnx_export)))
    model.eval()
    dummy_input = torch.LongTensor(seq_len * batch_size).zero_().view(-1, batch_size).to(device)
    hidden = model.init_hidden(batch_size)
    torch.onnx.export(model, (dummy_input, hidden), path)

# %%
# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, args.epochs+1):
        train()
except:
    print('-' * 89)
    print('Exiting from training early')
    writer.close()
writer.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:247: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# | epoch   1 |   200/22495 batches | lr 0.00004 | ms/batch 58.83 | loss 11.03 | ppl 61475.83
# | epoch   1 |   400/22495 batches | lr 0.00007 | ms/batch 37.13 | loss  8.94 | ppl  7658.21
# | epoch   1 |   600/22495 batches | lr 0.00010 | ms/batch 37.03 | loss  8.52 | ppl  5006.38
# | epoch   1 |   800/22495 batches | lr 0.00014 | ms/batch 37.38 | loss  8.34 | ppl  4197.86
# | epoch   1 |  1000/22495 batches | lr 0.00017 | ms/batch 37.41 | loss  8.30 | ppl  4009.47
# | epoch   1 |  1200/22495 batches | lr 0.00021 | ms/batch 37.41 | loss  8.12 | ppl  3362.22
# | epoch   1 |  1400/22495 batches | lr 0.00024 | ms/batch 37.39 | loss  7.92 | ppl  2745.80
# | epoch   1 |  1600/22495 batches | lr 0.00028 | ms/batch 37.29 | loss  7.84 | ppl  2548.99
# | epoch   1 |  1800/22495 batches | lr 0.00031 | ms/batch 37.32 | loss  7.71 | ppl  2228.39
# | epoch   1 |  2000/22495 batches | lr 0.00035 | ms/batch 37.29 | loss  7.54 | ppl  1878.15
# | epoch   1 |  2200/22495 batches | lr 0.00038 | ms/batch 37.26 | loss  7.57 | ppl  1941.55
# | epoch   1 |  2400/22495 batches | lr 0.00042 | ms/batch 36.65 | loss  7.48 | ppl  1771.49
# | epoch   1 |  2600/22495 batches | lr 0.00045 | ms/batch 36.31 | loss  7.39 | ppl  1614.21
# | epoch   1 |  2800/22495 batches | lr 0.00049 | ms/batch 36.23 | loss  7.30 | ppl  1475.84
# | epoch   1 |  3000/22495 batches | lr 0.00052 | ms/batch 36.14 | loss  7.23 | ppl  1385.07
# | epoch   1 |  3200/22495 batches | lr 0.00056 | ms/batch 36.43 | loss  7.10 | ppl  1215.43
# | epoch   1 |  3400/22495 batches | lr 0.00059 | ms/batch 36.14 | loss  7.07 | ppl  1171.36
# | epoch   1 |  3600/22495 batches | lr 0.00063 | ms/batch 36.20 | loss  6.98 | ppl  1076.91
# | epoch   1 |  3800/22495 batches | lr 0.00066 | ms/batch 36.01 | loss  7.05 | ppl  1149.65
# | epoch   1 |  4000/22495 batches | lr 0.00070 | ms/batch 36.44 | loss  7.03 | ppl  1128.15
# | epoch   1 |  4200/22495 batches | lr 0.00068 | ms/batch 36.24 | loss  7.04 | ppl  1136.19
# | epoch   1 |  4400/22495 batches | lr 0.00067 | ms/batch 36.03 | loss  6.96 | ppl  1056.73
# | epoch   1 |  4600/22495 batches | lr 0.00065 | ms/batch 35.96 | loss  7.02 | ppl  1121.58
# | epoch   1 |  4800/22495 batches | lr 0.00064 | ms/batch 36.02 | loss  6.98 | ppl  1079.75
# | epoch   1 |  5000/22495 batches | lr 0.00062 | ms/batch 36.20 | loss  6.91 | ppl  1005.22
# -----------------------------------------------------------------------------------------
# | end of iteration 5000 | valid loss  6.84 | valid ppl   938.87
# -----------------------------------------------------------------------------------------
# | epoch   1 |  5200/22495 batches | lr 0.00061 | ms/batch 176.21 | loss  6.92 | ppl  1015.28
# | epoch   1 |  5400/22495 batches | lr 0.00060 | ms/batch 36.51 | loss  6.85 | ppl   944.23
# | epoch   1 |  5600/22495 batches | lr 0.00059 | ms/batch 36.14 | loss  6.87 | ppl   958.46
# | epoch   1 |  5800/22495 batches | lr 0.00058 | ms/batch 36.15 | loss  6.86 | ppl   957.39
# | epoch   1 |  6000/22495 batches | lr 0.00057 | ms/batch 36.25 | loss  6.76 | ppl   860.47
# | epoch   1 |  6200/22495 batches | lr 0.00056 | ms/batch 36.27 | loss  6.76 | ppl   860.61
# | epoch   1 |  6400/22495 batches | lr 0.00055 | ms/batch 36.31 | loss  6.78 | ppl   879.37
# | epoch   1 |  6600/22495 batches | lr 0.00054 | ms/batch 36.34 | loss  6.81 | ppl   906.90
# | epoch   1 |  6800/22495 batches | lr 0.00054 | ms/batch 36.47 | loss  6.70 | ppl   811.41
# | epoch   1 |  7000/22495 batches | lr 0.00053 | ms/batch 36.21 | loss  6.70 | ppl   811.03
# | epoch   1 |  7200/22495 batches | lr 0.00052 | ms/batch 35.97 | loss  6.81 | ppl   902.38
# | epoch   1 |  7400/22495 batches | lr 0.00051 | ms/batch 36.20 | loss  6.75 | ppl   857.56
# | epoch   1 |  7600/22495 batches | lr 0.00051 | ms/batch 36.12 | loss  6.75 | ppl   854.29
# | epoch   1 |  7800/22495 batches | lr 0.00050 | ms/batch 36.34 | loss  6.77 | ppl   869.43
# | epoch   1 |  8000/22495 batches | lr 0.00049 | ms/batch 36.43 | loss  6.65 | ppl   774.62
# | epoch   1 |  8200/22495 batches | lr 0.00049 | ms/batch 36.22 | loss  6.63 | ppl   756.28
# | epoch   1 |  8400/22495 batches | lr 0.00048 | ms/batch 36.10 | loss  6.67 | ppl   789.19
# | epoch   1 |  8600/22495 batches | lr 0.00048 | ms/batch 36.08 | loss  6.73 | ppl   838.19
# | epoch   1 |  8800/22495 batches | lr 0.00047 | ms/batch 36.31 | loss  6.71 | ppl   822.59
# | epoch   1 |  9000/22495 batches | lr 0.00047 | ms/batch 36.27 | loss  6.67 | ppl   792.11
# | epoch   1 |  9200/22495 batches | lr 0.00046 | ms/batch 36.20 | loss  6.68 | ppl   795.73
# | epoch   1 |  9400/22495 batches | lr 0.00046 | ms/batch 36.10 | loss  6.59 | ppl   725.50
# | epoch   1 |  9600/22495 batches | lr 0.00045 | ms/batch 36.16 | loss  6.60 | ppl   737.77
# | epoch   1 |  9800/22495 batches | lr 0.00045 | ms/batch 36.33 | loss  6.57 | ppl   712.24
# | epoch   1 | 10000/22495 batches | lr 0.00044 | ms/batch 36.19 | loss  6.60 | ppl   736.20
# -----------------------------------------------------------------------------------------
# | end of iteration 10000 | valid loss  6.56 | valid ppl   709.08
# -----------------------------------------------------------------------------------------
# | epoch   1 | 10200/22495 batches | lr 0.00044 | ms/batch 177.29 | loss  6.53 | ppl   682.72
# | epoch   1 | 10400/22495 batches | lr 0.00043 | ms/batch 37.19 | loss  6.58 | ppl   722.48
# | epoch   1 | 10600/22495 batches | lr 0.00043 | ms/batch 36.49 | loss  6.61 | ppl   744.09
# | epoch   1 | 10800/22495 batches | lr 0.00043 | ms/batch 36.20 | loss  6.50 | ppl   667.36
# | epoch   1 | 11000/22495 batches | lr 0.00042 | ms/batch 36.25 | loss  6.58 | ppl   718.15
# | epoch   1 | 11200/22495 batches | lr 0.00042 | ms/batch 36.10 | loss  6.58 | ppl   724.01
# | epoch   1 | 11400/22495 batches | lr 0.00041 | ms/batch 36.05 | loss  6.54 | ppl   689.09
# | epoch   1 | 11600/22495 batches | lr 0.00041 | ms/batch 36.25 | loss  6.58 | ppl   720.54
# | epoch   1 | 11800/22495 batches | lr 0.00041 | ms/batch 36.20 | loss  6.59 | ppl   729.74
# | epoch   1 | 12000/22495 batches | lr 0.00040 | ms/batch 36.10 | loss  6.53 | ppl   688.17
# | epoch   1 | 12200/22495 batches | lr 0.00040 | ms/batch 36.17 | loss  6.58 | ppl   720.91
# | epoch   1 | 12400/22495 batches | lr 0.00040 | ms/batch 36.50 | loss  6.52 | ppl   678.52
# | epoch   1 | 12600/22495 batches | lr 0.00039 | ms/batch 36.16 | loss  6.53 | ppl   684.04
# | epoch   1 | 12800/22495 batches | lr 0.00039 | ms/batch 36.27 | loss  6.50 | ppl   667.83
# | epoch   1 | 13000/22495 batches | lr 0.00039 | ms/batch 36.16 | loss  6.49 | ppl   656.45
# | epoch   1 | 13200/22495 batches | lr 0.00038 | ms/batch 36.28 | loss  6.49 | ppl   657.10
# | epoch   1 | 13400/22495 batches | lr 0.00038 | ms/batch 36.16 | loss  6.47 | ppl   642.74
# | epoch   1 | 13600/22495 batches | lr 0.00038 | ms/batch 36.15 | loss  6.53 | ppl   685.99
# | epoch   1 | 13800/22495 batches | lr 0.00038 | ms/batch 36.28 | loss  6.48 | ppl   653.65
# | epoch   1 | 14000/22495 batches | lr 0.00037 | ms/batch 36.34 | loss  6.49 | ppl   657.22
# | epoch   1 | 14200/22495 batches | lr 0.00037 | ms/batch 36.16 | loss  6.49 | ppl   658.71
# | epoch   1 | 14400/22495 batches | lr 0.00037 | ms/batch 36.49 | loss  6.44 | ppl   625.43
# | epoch   1 | 14600/22495 batches | lr 0.00037 | ms/batch 36.37 | loss  6.42 | ppl   613.10
# | epoch   1 | 14800/22495 batches | lr 0.00036 | ms/batch 36.28 | loss  6.46 | ppl   642.07
# | epoch   1 | 15000/22495 batches | lr 0.00036 | ms/batch 36.27 | loss  6.46 | ppl   639.77
# -----------------------------------------------------------------------------------------
# | end of iteration 15000 | valid loss  6.43 | valid ppl   622.24
# -----------------------------------------------------------------------------------------
# | epoch   1 | 15200/22495 batches | lr 0.00036 | ms/batch 174.01 | loss  6.51 | ppl   671.99
# | epoch   1 | 15400/22495 batches | lr 0.00036 | ms/batch 38.48 | loss  6.49 | ppl   658.39
# | epoch   1 | 15600/22495 batches | lr 0.00035 | ms/batch 36.18 | loss  6.49 | ppl   660.06
# | epoch   1 | 15800/22495 batches | lr 0.00035 | ms/batch 36.23 | loss  6.44 | ppl   628.62
# | epoch   1 | 16000/22495 batches | lr 0.00035 | ms/batch 36.21 | loss  6.49 | ppl   656.39
# | epoch   1 | 16200/22495 batches | lr 0.00035 | ms/batch 36.31 | loss  6.43 | ppl   622.00
# | epoch   1 | 16400/22495 batches | lr 0.00035 | ms/batch 36.32 | loss  6.41 | ppl   610.92
# | epoch   1 | 16600/22495 batches | lr 0.00034 | ms/batch 36.40 | loss  6.46 | ppl   641.73
# | epoch   1 | 16800/22495 batches | lr 0.00034 | ms/batch 36.07 | loss  6.43 | ppl   620.17
# | epoch   1 | 17000/22495 batches | lr 0.00034 | ms/batch 36.14 | loss  6.42 | ppl   615.69
# | epoch   1 | 17200/22495 batches | lr 0.00034 | ms/batch 36.16 | loss  6.44 | ppl   624.47
# | epoch   1 | 17400/22495 batches | lr 0.00034 | ms/batch 36.15 | loss  6.44 | ppl   623.84
# | epoch   1 | 17600/22495 batches | lr 0.00033 | ms/batch 36.07 | loss  6.38 | ppl   589.82
# | epoch   1 | 17800/22495 batches | lr 0.00033 | ms/batch 36.12 | loss  6.38 | ppl   591.49
# | epoch   1 | 18000/22495 batches | lr 0.00033 | ms/batch 36.21 | loss  6.37 | ppl   581.63
# | epoch   1 | 18200/22495 batches | lr 0.00033 | ms/batch 36.29 | loss  6.38 | ppl   590.53
# | epoch   1 | 18400/22495 batches | lr 0.00033 | ms/batch 36.16 | loss  6.45 | ppl   632.95
# | epoch   1 | 18600/22495 batches | lr 0.00032 | ms/batch 36.16 | loss  6.38 | ppl   589.16
# | epoch   1 | 18800/22495 batches | lr 0.00032 | ms/batch 36.35 | loss  6.36 | ppl   580.94
# | epoch   1 | 19000/22495 batches | lr 0.00032 | ms/batch 36.21 | loss  6.37 | ppl   582.74
# | epoch   1 | 19200/22495 batches | lr 0.00032 | ms/batch 36.35 | loss  6.30 | ppl   543.91
# | epoch   1 | 19400/22495 batches | lr 0.00032 | ms/batch 36.11 | loss  6.41 | ppl   606.11
# | epoch   1 | 19600/22495 batches | lr 0.00032 | ms/batch 36.19 | loss  6.40 | ppl   601.00
# | epoch   1 | 19800/22495 batches | lr 0.00031 | ms/batch 36.34 | loss  6.40 | ppl   602.46
# | epoch   1 | 20000/22495 batches | lr 0.00031 | ms/batch 36.19 | loss  6.35 | ppl   571.26
# -----------------------------------------------------------------------------------------
# | end of iteration 20000 | valid loss  6.37 | valid ppl   581.34
# -----------------------------------------------------------------------------------------
# | epoch   1 | 20200/22495 batches | lr 0.00031 | ms/batch 173.69 | loss  6.33 | ppl   561.78
# | epoch   1 | 20400/22495 batches | lr 0.00031 | ms/batch 38.46 | loss  6.47 | ppl   644.69
# | epoch   1 | 20600/22495 batches | lr 0.00031 | ms/batch 36.11 | loss  6.37 | ppl   584.58
# | epoch   1 | 20800/22495 batches | lr 0.00031 | ms/batch 36.40 | loss  6.35 | ppl   572.18
# | epoch   1 | 21000/22495 batches | lr 0.00030 | ms/batch 36.20 | loss  6.34 | ppl   568.43
# | epoch   1 | 21200/22495 batches | lr 0.00030 | ms/batch 36.19 | loss  6.35 | ppl   573.86
# | epoch   1 | 21400/22495 batches | lr 0.00030 | ms/batch 36.39 | loss  6.36 | ppl   579.08
# | epoch   1 | 21600/22495 batches | lr 0.00030 | ms/batch 36.43 | loss  6.34 | ppl   564.47
# | epoch   1 | 21800/22495 batches | lr 0.00030 | ms/batch 36.15 | loss  6.27 | ppl   527.08
# | epoch   1 | 22000/22495 batches | lr 0.00030 | ms/batch 36.13 | loss  6.34 | ppl   568.35
# | epoch   1 | 22200/22495 batches | lr 0.00030 | ms/batch 36.38 | loss  6.33 | ppl   561.49
# | epoch   1 | 22400/22495 batches | lr 0.00030 | ms/batch 36.37 | loss  6.35 | ppl   574.52
# | epoch   2 |   200/22495 batches | lr 0.00029 | ms/batch 36.30 | loss  6.31 | ppl   547.76
# | epoch   2 |   400/22495 batches | lr 0.00029 | ms/batch 36.13 | loss  6.23 | ppl   510.10
# | epoch   2 |   600/22495 batches | lr 0.00029 | ms/batch 36.02 | loss  6.24 | ppl   511.84
# | epoch   2 |   800/22495 batches | lr 0.00029 | ms/batch 36.26 | loss  6.19 | ppl   490.26
# | epoch   2 |  1000/22495 batches | lr 0.00029 | ms/batch 36.11 | loss  6.30 | ppl   541.96
# | epoch   2 |  1200/22495 batches | lr 0.00029 | ms/batch 36.18 | loss  6.21 | ppl   499.41
# | epoch   2 |  1400/22495 batches | lr 0.00029 | ms/batch 36.13 | loss  6.20 | ppl   495.19
# | epoch   2 |  1600/22495 batches | lr 0.00028 | ms/batch 36.28 | loss  6.25 | ppl   519.12
# | epoch   2 |  1800/22495 batches | lr 0.00028 | ms/batch 36.14 | loss  6.20 | ppl   490.99
# | epoch   2 |  2000/22495 batches | lr 0.00028 | ms/batch 36.28 | loss  6.14 | ppl   461.96
# | epoch   2 |  2200/22495 batches | lr 0.00028 | ms/batch 36.33 | loss  6.24 | ppl   514.68
# | epoch   2 |  2400/22495 batches | lr 0.00028 | ms/batch 36.16 | loss  6.21 | ppl   495.90
# -----------------------------------------------------------------------------------------
# | end of iteration 25000 | valid loss  6.33 | valid ppl   560.94
# -----------------------------------------------------------------------------------------
# | epoch   2 |  2600/22495 batches | lr 0.00028 | ms/batch 173.12 | loss  6.19 | ppl   486.46
# | epoch   2 |  2800/22495 batches | lr 0.00028 | ms/batch 37.35 | loss  6.16 | ppl   475.53
# | epoch   2 |  3000/22495 batches | lr 0.00028 | ms/batch 37.05 | loss  6.20 | ppl   493.80
# | epoch   2 |  3200/22495 batches | lr 0.00028 | ms/batch 36.40 | loss  6.13 | ppl   459.18
# | epoch   2 |  3400/22495 batches | lr 0.00027 | ms/batch 36.28 | loss  6.14 | ppl   464.19
# | epoch   2 |  3600/22495 batches | lr 0.00027 | ms/batch 36.23 | loss  6.09 | ppl   441.72
# | epoch   2 |  3800/22495 batches | lr 0.00027 | ms/batch 36.20 | loss  6.17 | ppl   477.26
# | epoch   2 |  4000/22495 batches | lr 0.00027 | ms/batch 36.30 | loss  6.14 | ppl   463.63
# | epoch   2 |  4200/22495 batches | lr 0.00027 | ms/batch 36.11 | loss  6.17 | ppl   477.13
# | epoch   2 |  4400/22495 batches | lr 0.00027 | ms/batch 36.06 | loss  6.10 | ppl   446.80
# | epoch   2 |  4600/22495 batches | lr 0.00027 | ms/batch 36.06 | loss  6.18 | ppl   484.49
# | epoch   2 |  4800/22495 batches | lr 0.00027 | ms/batch 36.14 | loss  6.16 | ppl   475.57
# | epoch   2 |  5000/22495 batches | lr 0.00027 | ms/batch 36.25 | loss  6.14 | ppl   462.87
# | epoch   2 |  5200/22495 batches | lr 0.00027 | ms/batch 36.10 | loss  6.15 | ppl   470.61
# | epoch   2 |  5400/22495 batches | lr 0.00026 | ms/batch 36.27 | loss  6.11 | ppl   449.38
# | epoch   2 |  5600/22495 batches | lr 0.00026 | ms/batch 36.21 | loss  6.14 | ppl   463.34
# | epoch   2 |  5800/22495 batches | lr 0.00026 | ms/batch 36.34 | loss  6.16 | ppl   472.55
# | epoch   2 |  6000/22495 batches | lr 0.00026 | ms/batch 36.10 | loss  6.09 | ppl   443.39
# | epoch   2 |  6200/22495 batches | lr 0.00026 | ms/batch 36.07 | loss  6.10 | ppl   447.26
# | epoch   2 |  6400/22495 batches | lr 0.00026 | ms/batch 36.28 | loss  6.12 | ppl   456.67
# | epoch   2 |  6600/22495 batches | lr 0.00026 | ms/batch 36.47 | loss  6.18 | ppl   484.79
# | epoch   2 |  6800/22495 batches | lr 0.00026 | ms/batch 36.52 | loss  6.10 | ppl   446.17
# | epoch   2 |  7000/22495 batches | lr 0.00026 | ms/batch 36.30 | loss  6.09 | ppl   442.74
# | epoch   2 |  7200/22495 batches | lr 0.00026 | ms/batch 36.29 | loss  6.20 | ppl   492.83
# | epoch   2 |  7400/22495 batches | lr 0.00026 | ms/batch 36.22 | loss  6.17 | ppl   476.95
# -----------------------------------------------------------------------------------------
# | end of iteration 30000 | valid loss  6.27 | valid ppl   530.63
# -----------------------------------------------------------------------------------------
# | epoch   2 |  7600/22495 batches | lr 0.00025 | ms/batch 173.79 | loss  6.16 | ppl   471.81
# | epoch   2 |  7800/22495 batches | lr 0.00025 | ms/batch 38.43 | loss  6.19 | ppl   486.12
# | epoch   2 |  8000/22495 batches | lr 0.00025 | ms/batch 36.16 | loss  6.09 | ppl   439.97
# | epoch   2 |  8200/22495 batches | lr 0.00025 | ms/batch 36.30 | loss  6.07 | ppl   431.19
# | epoch   2 |  8400/22495 batches | lr 0.00025 | ms/batch 36.03 | loss  6.12 | ppl   456.28
# | epoch   2 |  8600/22495 batches | lr 0.00025 | ms/batch 36.10 | loss  6.20 | ppl   492.45
# | epoch   2 |  8800/22495 batches | lr 0.00025 | ms/batch 36.18 | loss  6.15 | ppl   469.12
# | epoch   2 |  9000/22495 batches | lr 0.00025 | ms/batch 36.14 | loss  6.15 | ppl   467.33
# | epoch   2 |  9200/22495 batches | lr 0.00025 | ms/batch 36.14 | loss  6.17 | ppl   477.87
# | epoch   2 |  9400/22495 batches | lr 0.00025 | ms/batch 36.09 | loss  6.09 | ppl   443.17
# | epoch   2 |  9600/22495 batches | lr 0.00025 | ms/batch 36.19 | loss  6.11 | ppl   450.71
# | epoch   2 |  9800/22495 batches | lr 0.00025 | ms/batch 36.10 | loss  6.07 | ppl   432.69
# | epoch   2 | 10000/22495 batches | lr 0.00025 | ms/batch 36.17 | loss  6.11 | ppl   451.39
# | epoch   2 | 10200/22495 batches | lr 0.00024 | ms/batch 36.02 | loss  6.05 | ppl   425.72
# | epoch   2 | 10400/22495 batches | lr 0.00024 | ms/batch 36.10 | loss  6.09 | ppl   442.11
# | epoch   2 | 10600/22495 batches | lr 0.00024 | ms/batch 36.18 | loss  6.16 | ppl   474.60
# | epoch   2 | 10800/22495 batches | lr 0.00024 | ms/batch 36.07 | loss  6.06 | ppl   430.44
# | epoch   2 | 11000/22495 batches | lr 0.00024 | ms/batch 36.14 | loss  6.11 | ppl   450.50
# | epoch   2 | 11200/22495 batches | lr 0.00024 | ms/batch 36.08 | loss  6.14 | ppl   463.65
# | epoch   2 | 11400/22495 batches | lr 0.00024 | ms/batch 36.24 | loss  6.09 | ppl   439.87
# | epoch   2 | 11600/22495 batches | lr 0.00024 | ms/batch 36.31 | loss  6.14 | ppl   462.10
# | epoch   2 | 11800/22495 batches | lr 0.00024 | ms/batch 36.11 | loss  6.13 | ppl   457.33
# | epoch   2 | 12000/22495 batches | lr 0.00024 | ms/batch 36.07 | loss  6.09 | ppl   443.41
# | epoch   2 | 12200/22495 batches | lr 0.00024 | ms/batch 36.09 | loss  6.14 | ppl   465.49
# | epoch   2 | 12400/22495 batches | lr 0.00024 | ms/batch 36.14 | loss  6.10 | ppl   445.56
# -----------------------------------------------------------------------------------------
# | end of iteration 35000 | valid loss  6.22 | valid ppl   500.27
# -----------------------------------------------------------------------------------------
# | epoch   2 | 12600/22495 batches | lr 0.00024 | ms/batch 172.91 | loss  6.12 | ppl   453.53
# | epoch   2 | 12800/22495 batches | lr 0.00024 | ms/batch 38.35 | loss  6.08 | ppl   436.97
# | epoch   2 | 13000/22495 batches | lr 0.00023 | ms/batch 36.09 | loss  6.10 | ppl   445.22
# | epoch   2 | 13200/22495 batches | lr 0.00023 | ms/batch 36.15 | loss  6.09 | ppl   440.81
# | epoch   2 | 13400/22495 batches | lr 0.00023 | ms/batch 36.37 | loss  6.07 | ppl   433.94
# | epoch   2 | 13600/22495 batches | lr 0.00023 | ms/batch 36.21 | loss  6.13 | ppl   459.65
# | epoch   2 | 13800/22495 batches | lr 0.00023 | ms/batch 36.30 | loss  6.09 | ppl   442.48
# | epoch   2 | 14000/22495 batches | lr 0.00023 | ms/batch 36.62 | loss  6.11 | ppl   450.07
# | epoch   2 | 14200/22495 batches | lr 0.00023 | ms/batch 36.23 | loss  6.11 | ppl   450.16
# | epoch   2 | 14400/22495 batches | lr 0.00023 | ms/batch 36.20 | loss  6.07 | ppl   431.06
# | epoch   2 | 14600/22495 batches | lr 0.00023 | ms/batch 36.99 | loss  6.05 | ppl   423.60
# | epoch   2 | 14800/22495 batches | lr 0.00023 | ms/batch 36.57 | loss  6.08 | ppl   437.58
# | epoch   2 | 15000/22495 batches | lr 0.00023 | ms/batch 36.99 | loss  6.10 | ppl   446.04
# | epoch   2 | 15200/22495 batches | lr 0.00023 | ms/batch 36.13 | loss  6.14 | ppl   463.16
# | epoch   2 | 15400/22495 batches | lr 0.00023 | ms/batch 36.43 | loss  6.12 | ppl   455.94
# | epoch   2 | 15600/22495 batches | lr 0.00023 | ms/batch 36.46 | loss  6.13 | ppl   458.19
# | epoch   2 | 15800/22495 batches | lr 0.00023 | ms/batch 36.34 | loss  6.10 | ppl   444.74
# | epoch   2 | 16000/22495 batches | lr 0.00023 | ms/batch 36.12 | loss  6.12 | ppl   456.57
# | epoch   2 | 16200/22495 batches | lr 0.00022 | ms/batch 37.52 | loss  6.10 | ppl   447.63
# | epoch   2 | 16400/22495 batches | lr 0.00022 | ms/batch 36.96 | loss  6.06 | ppl   429.80
# | epoch   2 | 16600/22495 batches | lr 0.00022 | ms/batch 36.42 | loss  6.13 | ppl   458.21
# | epoch   2 | 16800/22495 batches | lr 0.00022 | ms/batch 36.56 | loss  6.08 | ppl   435.53
# | epoch   2 | 17000/22495 batches | lr 0.00022 | ms/batch 36.46 | loss  6.09 | ppl   443.56
# | epoch   2 | 17200/22495 batches | lr 0.00022 | ms/batch 36.48 | loss  6.10 | ppl   444.18
# | epoch   2 | 17400/22495 batches | lr 0.00022 | ms/batch 36.58 | loss  6.08 | ppl   439.04
# -----------------------------------------------------------------------------------------
# | end of iteration 40000 | valid loss  6.17 | valid ppl   480.10
# -----------------------------------------------------------------------------------------
# | epoch   2 | 17600/22495 batches | lr 0.00022 | ms/batch 173.99 | loss  6.05 | ppl   426.13
# | epoch   2 | 17800/22495 batches | lr 0.00022 | ms/batch 38.66 | loss  6.06 | ppl   428.38
# | epoch   2 | 18000/22495 batches | lr 0.00022 | ms/batch 36.22 | loss  6.05 | ppl   422.76
# | epoch   2 | 18200/22495 batches | lr 0.00022 | ms/batch 36.32 | loss  6.06 | ppl   429.69
# | epoch   2 | 18400/22495 batches | lr 0.00022 | ms/batch 36.41 | loss  6.13 | ppl   459.30
# | epoch   2 | 18600/22495 batches | lr 0.00022 | ms/batch 36.27 | loss  6.08 | ppl   435.33
# | epoch   2 | 18800/22495 batches | lr 0.00022 | ms/batch 36.25 | loss  6.05 | ppl   424.64
# | epoch   2 | 19000/22495 batches | lr 0.00022 | ms/batch 36.32 | loss  6.06 | ppl   428.42
# | epoch   2 | 19200/22495 batches | lr 0.00022 | ms/batch 36.34 | loss  5.99 | ppl   398.23
# | epoch   2 | 19400/22495 batches | lr 0.00022 | ms/batch 36.17 | loss  6.10 | ppl   445.80
# | epoch   2 | 19600/22495 batches | lr 0.00022 | ms/batch 36.29 | loss  6.08 | ppl   437.66
# | epoch   2 | 19800/22495 batches | lr 0.00021 | ms/batch 36.21 | loss  6.10 | ppl   447.31
# | epoch   2 | 20000/22495 batches | lr 0.00021 | ms/batch 36.43 | loss  6.05 | ppl   424.39
# | epoch   2 | 20200/22495 batches | lr 0.00021 | ms/batch 36.22 | loss  6.05 | ppl   422.14
# | epoch   2 | 20400/22495 batches | lr 0.00021 | ms/batch 36.20 | loss  6.17 | ppl   479.66
# | epoch   2 | 20600/22495 batches | lr 0.00021 | ms/batch 36.20 | loss  6.07 | ppl   431.70
# | epoch   2 | 20800/22495 batches | lr 0.00021 | ms/batch 36.37 | loss  6.04 | ppl   421.31
# | epoch   2 | 21000/22495 batches | lr 0.00021 | ms/batch 36.56 | loss  6.05 | ppl   425.63
# | epoch   2 | 21200/22495 batches | lr 0.00021 | ms/batch 36.29 | loss  6.06 | ppl   427.79
# | epoch   2 | 21400/22495 batches | lr 0.00021 | ms/batch 36.52 | loss  6.09 | ppl   440.97
# | epoch   2 | 21600/22495 batches | lr 0.00021 | ms/batch 36.68 | loss  6.06 | ppl   427.52
# | epoch   2 | 21800/22495 batches | lr 0.00021 | ms/batch 36.87 | loss  5.99 | ppl   399.95
# | epoch   2 | 22000/22495 batches | lr 0.00021 | ms/batch 36.46 | loss  6.07 | ppl   432.73
# | epoch   2 | 22200/22495 batches | lr 0.00021 | ms/batch 36.37 | loss  6.06 | ppl   426.45
# | epoch   2 | 22400/22495 batches | lr 0.00021 | ms/batch 37.26 | loss  6.06 | ppl   428.52
# -----------------------------------------------------------------------------------------
# | end of iteration 45000 | valid loss  6.13 | valid ppl   461.68
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/22495 batches | lr 0.00021 | ms/batch 176.49 | loss  6.04 | ppl   421.50
# | epoch   3 |   400/22495 batches | lr 0.00021 | ms/batch 39.29 | loss  5.98 | ppl   395.67
# | epoch   3 |   600/22495 batches | lr 0.00021 | ms/batch 36.49 | loss  5.98 | ppl   396.11
# | epoch   3 |   800/22495 batches | lr 0.00021 | ms/batch 36.31 | loss  5.95 | ppl   382.13
# | epoch   3 |  1000/22495 batches | lr 0.00021 | ms/batch 36.44 | loss  6.06 | ppl   427.27
# | epoch   3 |  1200/22495 batches | lr 0.00021 | ms/batch 36.42 | loss  5.96 | ppl   388.31
# | epoch   3 |  1400/22495 batches | lr 0.00021 | ms/batch 36.38 | loss  5.96 | ppl   386.95
# | epoch   3 |  1600/22495 batches | lr 0.00020 | ms/batch 36.50 | loss  6.02 | ppl   410.09
# | epoch   3 |  1800/22495 batches | lr 0.00020 | ms/batch 36.31 | loss  5.98 | ppl   394.16
# | epoch   3 |  2000/22495 batches | lr 0.00020 | ms/batch 36.36 | loss  5.91 | ppl   370.19
# | epoch   3 |  2200/22495 batches | lr 0.00020 | ms/batch 36.55 | loss  6.02 | ppl   410.07
# | epoch   3 |  2400/22495 batches | lr 0.00020 | ms/batch 36.50 | loss  5.97 | ppl   392.34
# | epoch   3 |  2600/22495 batches | lr 0.00020 | ms/batch 36.57 | loss  5.97 | ppl   391.18
# | epoch   3 |  2800/22495 batches | lr 0.00020 | ms/batch 36.33 | loss  5.93 | ppl   375.68
# | epoch   3 |  3000/22495 batches | lr 0.00020 | ms/batch 36.42 | loss  5.99 | ppl   397.78
# | epoch   3 |  3200/22495 batches | lr 0.00020 | ms/batch 36.46 | loss  5.92 | ppl   374.12
# | epoch   3 |  3400/22495 batches | lr 0.00020 | ms/batch 36.14 | loss  5.93 | ppl   374.85
# | epoch   3 |  3600/22495 batches | lr 0.00020 | ms/batch 36.26 | loss  5.87 | ppl   355.22
# | epoch   3 |  3800/22495 batches | lr 0.00020 | ms/batch 36.45 | loss  5.95 | ppl   384.07
# | epoch   3 |  4000/22495 batches | lr 0.00020 | ms/batch 36.42 | loss  5.93 | ppl   376.85
# | epoch   3 |  4200/22495 batches | lr 0.00020 | ms/batch 36.42 | loss  5.97 | ppl   391.76
# | epoch   3 |  4400/22495 batches | lr 0.00020 | ms/batch 36.22 | loss  5.91 | ppl   367.74
# | epoch   3 |  4600/22495 batches | lr 0.00020 | ms/batch 36.18 | loss  5.98 | ppl   395.02
# | epoch   3 |  4800/22495 batches | lr 0.00020 | ms/batch 36.50 | loss  5.96 | ppl   386.82
# | epoch   3 |  5000/22495 batches | lr 0.00020 | ms/batch 36.49 | loss  5.92 | ppl   372.85
# -----------------------------------------------------------------------------------------
# | end of iteration 50000 | valid loss  6.14 | valid ppl   463.41
# -----------------------------------------------------------------------------------------
# | epoch   3 |  5200/22495 batches | lr 0.00020 | ms/batch 169.27 | loss  5.93 | ppl   376.29
# | epoch   3 |  5400/22495 batches | lr 0.00020 | ms/batch 36.33 | loss  5.89 | ppl   361.04
# | epoch   3 |  5600/22495 batches | lr 0.00020 | ms/batch 36.60 | loss  5.92 | ppl   372.94
# | epoch   3 |  5800/22495 batches | lr 0.00020 | ms/batch 36.42 | loss  5.94 | ppl   379.34
# | epoch   3 |  6000/22495 batches | lr 0.00020 | ms/batch 36.30 | loss  5.89 | ppl   361.93
# | epoch   3 |  6200/22495 batches | lr 0.00020 | ms/batch 36.44 | loss  5.90 | ppl   366.09
# | epoch   3 |  6400/22495 batches | lr 0.00019 | ms/batch 36.36 | loss  5.91 | ppl   370.34
# | epoch   3 |  6600/22495 batches | lr 0.00019 | ms/batch 36.19 | loss  5.97 | ppl   392.09
# | epoch   3 |  6800/22495 batches | lr 0.00019 | ms/batch 36.35 | loss  5.88 | ppl   359.52
# | epoch   3 |  7000/22495 batches | lr 0.00019 | ms/batch 36.24 | loss  5.88 | ppl   358.32
# | epoch   3 |  7200/22495 batches | lr 0.00019 | ms/batch 36.21 | loss  5.99 | ppl   398.48
# | epoch   3 |  7400/22495 batches | lr 0.00019 | ms/batch 36.37 | loss  5.96 | ppl   387.00
# | epoch   3 |  7600/22495 batches | lr 0.00019 | ms/batch 36.24 | loss  5.95 | ppl   382.33
# | epoch   3 |  7800/22495 batches | lr 0.00019 | ms/batch 36.29 | loss  5.97 | ppl   390.35
# | epoch   3 |  8000/22495 batches | lr 0.00019 | ms/batch 36.31 | loss  5.89 | ppl   361.80
# | epoch   3 |  8200/22495 batches | lr 0.00019 | ms/batch 36.23 | loss  5.89 | ppl   361.34
# | epoch   3 |  8400/22495 batches | lr 0.00019 | ms/batch 36.22 | loss  5.91 | ppl   367.93
# | epoch   3 |  8600/22495 batches | lr 0.00019 | ms/batch 36.38 | loss  6.00 | ppl   403.75
# | epoch   3 |  8800/22495 batches | lr 0.00019 | ms/batch 36.11 | loss  5.95 | ppl   384.17
# | epoch   3 |  9000/22495 batches | lr 0.00019 | ms/batch 36.18 | loss  5.95 | ppl   382.66
# | epoch   3 |  9200/22495 batches | lr 0.00019 | ms/batch 36.33 | loss  5.99 | ppl   398.00
# | epoch   3 |  9400/22495 batches | lr 0.00019 | ms/batch 36.05 | loss  5.90 | ppl   365.50
# | epoch   3 |  9600/22495 batches | lr 0.00019 | ms/batch 36.29 | loss  5.92 | ppl   374.10
# | epoch   3 |  9800/22495 batches | lr 0.00019 | ms/batch 36.24 | loss  5.89 | ppl   360.18
# | epoch   3 | 10000/22495 batches | lr 0.00019 | ms/batch 36.10 | loss  5.92 | ppl   372.31
# -----------------------------------------------------------------------------------------
# | end of iteration 55000 | valid loss  6.10 | valid ppl   443.82
# -----------------------------------------------------------------------------------------
# | epoch   3 | 10200/22495 batches | lr 0.00019 | ms/batch 175.40 | loss  5.87 | ppl   354.63
# | epoch   3 | 10400/22495 batches | lr 0.00019 | ms/batch 38.29 | loss  5.90 | ppl   365.13
# | epoch   3 | 10600/22495 batches | lr 0.00019 | ms/batch 36.35 | loss  5.96 | ppl   386.45
# | epoch   3 | 10800/22495 batches | lr 0.00019 | ms/batch 36.12 | loss  5.87 | ppl   352.80
# | epoch   3 | 11000/22495 batches | lr 0.00019 | ms/batch 36.08 | loss  5.91 | ppl   367.03
# | epoch   3 | 11200/22495 batches | lr 0.00019 | ms/batch 36.06 | loss  5.95 | ppl   385.19
# | epoch   3 | 11400/22495 batches | lr 0.00019 | ms/batch 35.98 | loss  5.89 | ppl   362.76
# | epoch   3 | 11600/22495 batches | lr 0.00019 | ms/batch 36.34 | loss  5.94 | ppl   379.47
# | epoch   3 | 11800/22495 batches | lr 0.00019 | ms/batch 36.04 | loss  5.93 | ppl   377.79
# | epoch   3 | 12000/22495 batches | lr 0.00019 | ms/batch 36.19 | loss  5.90 | ppl   365.25
# | epoch   3 | 12200/22495 batches | lr 0.00018 | ms/batch 36.19 | loss  5.94 | ppl   381.05
# | epoch   3 | 12400/22495 batches | lr 0.00018 | ms/batch 36.17 | loss  5.90 | ppl   365.75
# | epoch   3 | 12600/22495 batches | lr 0.00018 | ms/batch 36.28 | loss  5.92 | ppl   372.67
# | epoch   3 | 12800/22495 batches | lr 0.00018 | ms/batch 36.09 | loss  5.89 | ppl   360.73
# | epoch   3 | 13000/22495 batches | lr 0.00018 | ms/batch 36.22 | loss  5.91 | ppl   367.32
# | epoch   3 | 13200/22495 batches | lr 0.00018 | ms/batch 36.32 | loss  5.90 | ppl   364.92
# | epoch   3 | 13400/22495 batches | lr 0.00018 | ms/batch 36.27 | loss  5.89 | ppl   362.07
# | epoch   3 | 13600/22495 batches | lr 0.00018 | ms/batch 36.18 | loss  5.94 | ppl   378.33
# | epoch   3 | 13800/22495 batches | lr 0.00018 | ms/batch 36.00 | loss  5.91 | ppl   367.56
# | epoch   3 | 14000/22495 batches | lr 0.00018 | ms/batch 36.56 | loss  5.92 | ppl   373.53
# | epoch   3 | 14200/22495 batches | lr 0.00018 | ms/batch 36.25 | loss  5.93 | ppl   376.62
# | epoch   3 | 14400/22495 batches | lr 0.00018 | ms/batch 36.27 | loss  5.89 | ppl   362.41
# | epoch   3 | 14600/22495 batches | lr 0.00018 | ms/batch 36.11 | loss  5.88 | ppl   356.30
# | epoch   3 | 14800/22495 batches | lr 0.00018 | ms/batch 36.09 | loss  5.90 | ppl   365.00
# | epoch   3 | 15000/22495 batches | lr 0.00018 | ms/batch 36.18 | loss  5.92 | ppl   371.24
# -----------------------------------------------------------------------------------------
# | end of iteration 60000 | valid loss  6.07 | valid ppl   431.13
# -----------------------------------------------------------------------------------------
# | epoch   3 | 15200/22495 batches | lr 0.00018 | ms/batch 173.51 | loss  5.95 | ppl   382.93
# | epoch   3 | 15400/22495 batches | lr 0.00018 | ms/batch 37.52 | loss  5.95 | ppl   385.58
# | epoch   3 | 15600/22495 batches | lr 0.00018 | ms/batch 36.18 | loss  5.94 | ppl   378.10
# | epoch   3 | 15800/22495 batches | lr 0.00018 | ms/batch 36.34 | loss  5.93 | ppl   374.49
# | epoch   3 | 16000/22495 batches | lr 0.00018 | ms/batch 36.22 | loss  5.94 | ppl   378.85
# | epoch   3 | 16200/22495 batches | lr 0.00018 | ms/batch 36.21 | loss  5.91 | ppl   367.32
# | epoch   3 | 16400/22495 batches | lr 0.00018 | ms/batch 36.20 | loss  5.89 | ppl   359.70
# | epoch   3 | 16600/22495 batches | lr 0.00018 | ms/batch 36.20 | loss  5.95 | ppl   383.39
# | epoch   3 | 16800/22495 batches | lr 0.00018 | ms/batch 36.11 | loss  5.91 | ppl   366.91
# | epoch   3 | 17000/22495 batches | lr 0.00018 | ms/batch 36.08 | loss  5.91 | ppl   369.44
# | epoch   3 | 17200/22495 batches | lr 0.00018 | ms/batch 36.17 | loss  5.92 | ppl   370.68
# | epoch   3 | 17400/22495 batches | lr 0.00018 | ms/batch 36.20 | loss  5.92 | ppl   371.40
# | epoch   3 | 17600/22495 batches | lr 0.00018 | ms/batch 36.16 | loss  5.87 | ppl   353.96
# | epoch   3 | 17800/22495 batches | lr 0.00018 | ms/batch 36.11 | loss  5.89 | ppl   359.67
# | epoch   3 | 18000/22495 batches | lr 0.00018 | ms/batch 36.19 | loss  5.89 | ppl   360.48
# | epoch   3 | 18200/22495 batches | lr 0.00018 | ms/batch 36.13 | loss  5.89 | ppl   360.69
# | epoch   3 | 18400/22495 batches | lr 0.00018 | ms/batch 35.96 | loss  5.96 | ppl   387.75
# | epoch   3 | 18600/22495 batches | lr 0.00018 | ms/batch 36.20 | loss  5.89 | ppl   361.81
# | epoch   3 | 18800/22495 batches | lr 0.00017 | ms/batch 36.19 | loss  5.87 | ppl   355.47
# | epoch   3 | 19000/22495 batches | lr 0.00017 | ms/batch 36.18 | loss  5.90 | ppl   364.63
# | epoch   3 | 19200/22495 batches | lr 0.00017 | ms/batch 36.16 | loss  5.82 | ppl   335.84
# | epoch   3 | 19400/22495 batches | lr 0.00017 | ms/batch 36.10 | loss  5.94 | ppl   379.53
# | epoch   3 | 19600/22495 batches | lr 0.00017 | ms/batch 36.15 | loss  5.91 | ppl   370.55
# | epoch   3 | 19800/22495 batches | lr 0.00017 | ms/batch 36.06 | loss  5.94 | ppl   378.28
# | epoch   3 | 20000/22495 batches | lr 0.00017 | ms/batch 36.33 | loss  5.87 | ppl   353.43
# -----------------------------------------------------------------------------------------
# | end of iteration 65000 | valid loss  6.06 | valid ppl   427.95
# -----------------------------------------------------------------------------------------
# | epoch   3 | 20200/22495 batches | lr 0.00017 | ms/batch 175.87 | loss  5.88 | ppl   359.03
# | epoch   3 | 20400/22495 batches | lr 0.00017 | ms/batch 37.23 | loss  5.98 | ppl   396.08
# | epoch   3 | 20600/22495 batches | lr 0.00017 | ms/batch 36.22 | loss  5.90 | ppl   365.93
# | epoch   3 | 20800/22495 batches | lr 0.00017 | ms/batch 36.28 | loss  5.87 | ppl   354.06
# | epoch   3 | 21000/22495 batches | lr 0.00017 | ms/batch 36.43 | loss  5.89 | ppl   360.26
# | epoch   3 | 21200/22495 batches | lr 0.00017 | ms/batch 36.27 | loss  5.89 | ppl   360.20
# | epoch   3 | 21400/22495 batches | lr 0.00017 | ms/batch 36.18 | loss  5.92 | ppl   371.72
# | epoch   3 | 21600/22495 batches | lr 0.00017 | ms/batch 36.08 | loss  5.90 | ppl   364.61
# | epoch   3 | 21800/22495 batches | lr 0.00017 | ms/batch 36.43 | loss  5.83 | ppl   339.86
# | epoch   3 | 22000/22495 batches | lr 0.00017 | ms/batch 36.17 | loss  5.90 | ppl   364.99
# | epoch   3 | 22200/22495 batches | lr 0.00017 | ms/batch 36.14 | loss  5.88 | ppl   357.29
# | epoch   3 | 22400/22495 batches | lr 0.00017 | ms/batch 36.23 | loss  5.90 | ppl   363.50
# | epoch   4 |   200/22495 batches | lr 0.00017 | ms/batch 36.50 | loss  5.89 | ppl   362.43
# | epoch   4 |   400/22495 batches | lr 0.00017 | ms/batch 36.17 | loss  5.83 | ppl   341.66
# | epoch   4 |   600/22495 batches | lr 0.00017 | ms/batch 36.25 | loss  5.83 | ppl   341.81
# | epoch   4 |   800/22495 batches | lr 0.00017 | ms/batch 36.20 | loss  5.79 | ppl   325.52
# | epoch   4 |  1000/22495 batches | lr 0.00017 | ms/batch 36.14 | loss  5.89 | ppl   362.85
# | epoch   4 |  1200/22495 batches | lr 0.00017 | ms/batch 36.19 | loss  5.83 | ppl   341.15
# | epoch   4 |  1400/22495 batches | lr 0.00017 | ms/batch 36.14 | loss  5.82 | ppl   336.38
# | epoch   4 |  1600/22495 batches | lr 0.00017 | ms/batch 36.23 | loss  5.86 | ppl   352.01
# | epoch   4 |  1800/22495 batches | lr 0.00017 | ms/batch 36.13 | loss  5.84 | ppl   342.19
# | epoch   4 |  2000/22495 batches | lr 0.00017 | ms/batch 36.25 | loss  5.77 | ppl   319.62
# | epoch   4 |  2200/22495 batches | lr 0.00017 | ms/batch 36.27 | loss  5.88 | ppl   358.51
# | epoch   4 |  2400/22495 batches | lr 0.00017 | ms/batch 36.11 | loss  5.82 | ppl   338.11
# -----------------------------------------------------------------------------------------
# | end of iteration 70000 | valid loss  6.07 | valid ppl   433.96
# -----------------------------------------------------------------------------------------
# | epoch   4 |  2600/22495 batches | lr 0.00017 | ms/batch 168.69 | loss  5.81 | ppl   334.86
# | epoch   4 |  2800/22495 batches | lr 0.00017 | ms/batch 36.12 | loss  5.80 | ppl   328.97
# | epoch   4 |  3000/22495 batches | lr 0.00017 | ms/batch 36.13 | loss  5.85 | ppl   347.17
# | epoch   4 |  3200/22495 batches | lr 0.00017 | ms/batch 36.22 | loss  5.79 | ppl   325.90
# | epoch   4 |  3400/22495 batches | lr 0.00017 | ms/batch 36.43 | loss  5.79 | ppl   326.73
# | epoch   4 |  3600/22495 batches | lr 0.00017 | ms/batch 36.08 | loss  5.74 | ppl   309.62
# | epoch   4 |  3800/22495 batches | lr 0.00017 | ms/batch 36.09 | loss  5.81 | ppl   333.21
# | epoch   4 |  4000/22495 batches | lr 0.00017 | ms/batch 36.04 | loss  5.81 | ppl   331.96
# | epoch   4 |  4200/22495 batches | lr 0.00017 | ms/batch 36.17 | loss  5.82 | ppl   338.00
# | epoch   4 |  4400/22495 batches | lr 0.00016 | ms/batch 36.18 | loss  5.78 | ppl   323.53
# | epoch   4 |  4600/22495 batches | lr 0.00016 | ms/batch 36.05 | loss  5.83 | ppl   341.61
# | epoch   4 |  4800/22495 batches | lr 0.00016 | ms/batch 36.18 | loss  5.79 | ppl   328.61
# | epoch   4 |  5000/22495 batches | lr 0.00016 | ms/batch 36.48 | loss  5.79 | ppl   326.35
# | epoch   4 |  5200/22495 batches | lr 0.00016 | ms/batch 36.47 | loss  5.80 | ppl   331.53
# | epoch   4 |  5400/22495 batches | lr 0.00016 | ms/batch 36.16 | loss  5.76 | ppl   316.25
# | epoch   4 |  5600/22495 batches | lr 0.00016 | ms/batch 36.12 | loss  5.79 | ppl   327.56
# | epoch   4 |  5800/22495 batches | lr 0.00016 | ms/batch 36.10 | loss  5.81 | ppl   334.35
# | epoch   4 |  6000/22495 batches | lr 0.00016 | ms/batch 36.14 | loss  5.76 | ppl   317.10
# | epoch   4 |  6200/22495 batches | lr 0.00016 | ms/batch 36.23 | loss  5.77 | ppl   320.57
# | epoch   4 |  6400/22495 batches | lr 0.00016 | ms/batch 36.38 | loss  5.77 | ppl   321.68
# | epoch   4 |  6600/22495 batches | lr 0.00016 | ms/batch 36.20 | loss  5.85 | ppl   345.62
# | epoch   4 |  6800/22495 batches | lr 0.00016 | ms/batch 36.36 | loss  5.78 | ppl   324.60
# | epoch   4 |  7000/22495 batches | lr 0.00016 | ms/batch 36.13 | loss  5.76 | ppl   317.23
# | epoch   4 |  7200/22495 batches | lr 0.00016 | ms/batch 36.12 | loss  5.86 | ppl   351.30
# | epoch   4 |  7400/22495 batches | lr 0.00016 | ms/batch 36.04 | loss  5.83 | ppl   339.17
# -----------------------------------------------------------------------------------------
# | end of iteration 75000 | valid loss  6.03 | valid ppl   413.89
# -----------------------------------------------------------------------------------------
# | epoch   4 |  7600/22495 batches | lr 0.00016 | ms/batch 174.02 | loss  5.81 | ppl   332.01
# | epoch   4 |  7800/22495 batches | lr 0.00016 | ms/batch 38.58 | loss  5.85 | ppl   345.64
# | epoch   4 |  8000/22495 batches | lr 0.00016 | ms/batch 36.07 | loss  5.78 | ppl   322.71
# | epoch   4 |  8200/22495 batches | lr 0.00016 | ms/batch 36.03 | loss  5.76 | ppl   318.70
# | epoch   4 |  8400/22495 batches | lr 0.00016 | ms/batch 36.05 | loss  5.79 | ppl   326.39
# | epoch   4 |  8600/22495 batches | lr 0.00016 | ms/batch 36.16 | loss  5.87 | ppl   353.85
# | epoch   4 |  8800/22495 batches | lr 0.00016 | ms/batch 36.23 | loss  5.82 | ppl   337.77
# | epoch   4 |  9000/22495 batches | lr 0.00016 | ms/batch 36.15 | loss  5.83 | ppl   339.08
# | epoch   4 |  9200/22495 batches | lr 0.00016 | ms/batch 36.19 | loss  5.87 | ppl   352.64
# | epoch   4 |  9400/22495 batches | lr 0.00016 | ms/batch 36.17 | loss  5.77 | ppl   319.19
# | epoch   4 |  9600/22495 batches | lr 0.00016 | ms/batch 36.00 | loss  5.80 | ppl   329.06
# | epoch   4 |  9800/22495 batches | lr 0.00016 | ms/batch 36.17 | loss  5.75 | ppl   315.57
# | epoch   4 | 10000/22495 batches | lr 0.00016 | ms/batch 36.10 | loss  5.79 | ppl   326.69
# | epoch   4 | 10200/22495 batches | lr 0.00016 | ms/batch 36.14 | loss  5.74 | ppl   312.48
# | epoch   4 | 10400/22495 batches | lr 0.00016 | ms/batch 36.04 | loss  5.76 | ppl   317.27
# | epoch   4 | 10600/22495 batches | lr 0.00016 | ms/batch 36.23 | loss  5.83 | ppl   340.91
# | epoch   4 | 10800/22495 batches | lr 0.00016 | ms/batch 36.11 | loss  5.74 | ppl   311.02
# | epoch   4 | 11000/22495 batches | lr 0.00016 | ms/batch 36.23 | loss  5.78 | ppl   325.36
# | epoch   4 | 11200/22495 batches | lr 0.00016 | ms/batch 36.18 | loss  5.83 | ppl   340.51
# | epoch   4 | 11400/22495 batches | lr 0.00016 | ms/batch 36.20 | loss  5.77 | ppl   321.37
# | epoch   4 | 11600/22495 batches | lr 0.00016 | ms/batch 36.15 | loss  5.81 | ppl   333.68
# | epoch   4 | 11800/22495 batches | lr 0.00016 | ms/batch 36.08 | loss  5.80 | ppl   330.12
# | epoch   4 | 12000/22495 batches | lr 0.00016 | ms/batch 36.21 | loss  5.78 | ppl   323.71
# | epoch   4 | 12200/22495 batches | lr 0.00016 | ms/batch 36.07 | loss  5.82 | ppl   335.65
# | epoch   4 | 12400/22495 batches | lr 0.00016 | ms/batch 36.49 | loss  5.77 | ppl   321.74
# -----------------------------------------------------------------------------------------
# | end of iteration 80000 | valid loss  6.01 | valid ppl   407.01
# -----------------------------------------------------------------------------------------
# | epoch   4 | 12600/22495 batches | lr 0.00016 | ms/batch 173.90 | loss  5.80 | ppl   331.59
# | epoch   4 | 12800/22495 batches | lr 0.00016 | ms/batch 38.26 | loss  5.77 | ppl   319.14
# | epoch   4 | 13000/22495 batches | lr 0.00016 | ms/batch 36.15 | loss  5.79 | ppl   328.54
# | epoch   4 | 13200/22495 batches | lr 0.00016 | ms/batch 36.16 | loss  5.77 | ppl   320.25
# | epoch   4 | 13400/22495 batches | lr 0.00016 | ms/batch 36.46 | loss  5.76 | ppl   318.22
# | epoch   4 | 13600/22495 batches | lr 0.00016 | ms/batch 36.42 | loss  5.82 | ppl   336.79
# | epoch   4 | 13800/22495 batches | lr 0.00016 | ms/batch 36.02 | loss  5.80 | ppl   329.18
# | epoch   4 | 14000/22495 batches | lr 0.00015 | ms/batch 36.06 | loss  5.80 | ppl   329.92
# | epoch   4 | 14200/22495 batches | lr 0.00015 | ms/batch 36.14 | loss  5.81 | ppl   335.09
# | epoch   4 | 14400/22495 batches | lr 0.00015 | ms/batch 36.19 | loss  5.77 | ppl   321.28
# | epoch   4 | 14600/22495 batches | lr 0.00015 | ms/batch 36.14 | loss  5.77 | ppl   319.69
# | epoch   4 | 14800/22495 batches | lr 0.00015 | ms/batch 36.18 | loss  5.78 | ppl   323.33
# | epoch   4 | 15000/22495 batches | lr 0.00015 | ms/batch 36.12 | loss  5.80 | ppl   328.83
# | epoch   4 | 15200/22495 batches | lr 0.00015 | ms/batch 36.22 | loss  5.82 | ppl   336.18
# | epoch   4 | 15400/22495 batches | lr 0.00015 | ms/batch 36.08 | loss  5.82 | ppl   337.38
# | epoch   4 | 15600/22495 batches | lr 0.00015 | ms/batch 36.15 | loss  5.82 | ppl   338.36
# | epoch   4 | 15800/22495 batches | lr 0.00015 | ms/batch 36.00 | loss  5.80 | ppl   330.64
# | epoch   4 | 16000/22495 batches | lr 0.00015 | ms/batch 36.10 | loss  5.83 | ppl   341.31
# | epoch   4 | 16200/22495 batches | lr 0.00015 | ms/batch 36.29 | loss  5.79 | ppl   328.07
# | epoch   4 | 16400/22495 batches | lr 0.00015 | ms/batch 36.03 | loss  5.77 | ppl   320.74
# | epoch   4 | 16600/22495 batches | lr 0.00015 | ms/batch 36.10 | loss  5.83 | ppl   339.42
# | epoch   4 | 16800/22495 batches | lr 0.00015 | ms/batch 36.34 | loss  5.79 | ppl   325.85
# | epoch   4 | 17000/22495 batches | lr 0.00015 | ms/batch 36.10 | loss  5.79 | ppl   326.86
# | epoch   4 | 17200/22495 batches | lr 0.00015 | ms/batch 36.24 | loss  5.79 | ppl   325.55
# | epoch   4 | 17400/22495 batches | lr 0.00015 | ms/batch 36.09 | loss  5.80 | ppl   330.09
# -----------------------------------------------------------------------------------------
# | end of iteration 85000 | valid loss  5.99 | valid ppl   398.40
# -----------------------------------------------------------------------------------------
# | epoch   4 | 17600/22495 batches | lr 0.00015 | ms/batch 173.44 | loss  5.75 | ppl   313.91
# | epoch   4 | 17800/22495 batches | lr 0.00015 | ms/batch 38.11 | loss  5.77 | ppl   322.06
# | epoch   4 | 18000/22495 batches | lr 0.00015 | ms/batch 36.42 | loss  5.76 | ppl   318.79
# | epoch   4 | 18200/22495 batches | lr 0.00015 | ms/batch 36.26 | loss  5.77 | ppl   319.92
# | epoch   4 | 18400/22495 batches | lr 0.00015 | ms/batch 36.06 | loss  5.83 | ppl   341.40
# | epoch   4 | 18600/22495 batches | lr 0.00015 | ms/batch 36.25 | loss  5.78 | ppl   323.13
# | epoch   4 | 18800/22495 batches | lr 0.00015 | ms/batch 36.13 | loss  5.76 | ppl   317.56
# | epoch   4 | 19000/22495 batches | lr 0.00015 | ms/batch 36.06 | loss  5.78 | ppl   324.52
# | epoch   4 | 19200/22495 batches | lr 0.00015 | ms/batch 36.40 | loss  5.70 | ppl   298.42
# | epoch   4 | 19400/22495 batches | lr 0.00015 | ms/batch 36.28 | loss  5.81 | ppl   334.90
# | epoch   4 | 19600/22495 batches | lr 0.00015 | ms/batch 36.26 | loss  5.80 | ppl   328.78
# | epoch   4 | 19800/22495 batches | lr 0.00015 | ms/batch 36.24 | loss  5.81 | ppl   334.84
# | epoch   4 | 20000/22495 batches | lr 0.00015 | ms/batch 36.23 | loss  5.76 | ppl   316.66
# | epoch   4 | 20200/22495 batches | lr 0.00015 | ms/batch 36.10 | loss  5.77 | ppl   320.30
# | epoch   4 | 20400/22495 batches | lr 0.00015 | ms/batch 36.26 | loss  5.86 | ppl   351.95
# | epoch   4 | 20600/22495 batches | lr 0.00015 | ms/batch 36.09 | loss  5.79 | ppl   325.60
# | epoch   4 | 20800/22495 batches | lr 0.00015 | ms/batch 36.16 | loss  5.76 | ppl   317.88
# | epoch   4 | 21000/22495 batches | lr 0.00015 | ms/batch 36.28 | loss  5.77 | ppl   320.18
# | epoch   4 | 21200/22495 batches | lr 0.00015 | ms/batch 36.37 | loss  5.76 | ppl   317.77
# | epoch   4 | 21400/22495 batches | lr 0.00015 | ms/batch 36.21 | loss  5.80 | ppl   331.17
# | epoch   4 | 21600/22495 batches | lr 0.00015 | ms/batch 35.99 | loss  5.77 | ppl   322.05
# | epoch   4 | 21800/22495 batches | lr 0.00015 | ms/batch 36.16 | loss  5.71 | ppl   302.65
# | epoch   4 | 22000/22495 batches | lr 0.00015 | ms/batch 35.99 | loss  5.78 | ppl   323.58
# | epoch   4 | 22200/22495 batches | lr 0.00015 | ms/batch 36.23 | loss  5.77 | ppl   319.20
# | epoch   4 | 22400/22495 batches | lr 0.00015 | ms/batch 36.10 | loss  5.78 | ppl   323.37
# -----------------------------------------------------------------------------------------
# | end of iteration 90000 | valid loss  5.96 | valid ppl   387.47
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/22495 batches | lr 0.00015 | ms/batch 174.71 | loss  5.78 | ppl   324.74
# | epoch   5 |   400/22495 batches | lr 0.00015 | ms/batch 38.46 | loss  5.72 | ppl   305.43
# | epoch   5 |   600/22495 batches | lr 0.00015 | ms/batch 36.05 | loss  5.72 | ppl   304.96
# | epoch   5 |   800/22495 batches | lr 0.00015 | ms/batch 36.08 | loss  5.67 | ppl   291.42
# | epoch   5 |  1000/22495 batches | lr 0.00015 | ms/batch 36.19 | loss  5.78 | ppl   324.29
# | epoch   5 |  1200/22495 batches | lr 0.00015 | ms/batch 36.25 | loss  5.72 | ppl   305.18
# | epoch   5 |  1400/22495 batches | lr 0.00015 | ms/batch 36.20 | loss  5.72 | ppl   306.22
# | epoch   5 |  1600/22495 batches | lr 0.00015 | ms/batch 36.19 | loss  5.76 | ppl   316.49
# | epoch   5 |  1800/22495 batches | lr 0.00015 | ms/batch 36.07 | loss  5.72 | ppl   303.45
# | epoch   5 |  2000/22495 batches | lr 0.00015 | ms/batch 36.08 | loss  5.68 | ppl   291.57
# | epoch   5 |  2200/22495 batches | lr 0.00015 | ms/batch 36.13 | loss  5.77 | ppl   319.84
# | epoch   5 |  2400/22495 batches | lr 0.00015 | ms/batch 36.12 | loss  5.74 | ppl   309.85
# | epoch   5 |  2600/22495 batches | lr 0.00015 | ms/batch 36.13 | loss  5.71 | ppl   300.81
# | epoch   5 |  2800/22495 batches | lr 0.00015 | ms/batch 36.24 | loss  5.69 | ppl   296.37
# | epoch   5 |  3000/22495 batches | lr 0.00014 | ms/batch 36.07 | loss  5.75 | ppl   313.23
# | epoch   5 |  3200/22495 batches | lr 0.00014 | ms/batch 36.16 | loss  5.68 | ppl   293.38
# | epoch   5 |  3400/22495 batches | lr 0.00014 | ms/batch 36.03 | loss  5.69 | ppl   296.54
# | epoch   5 |  3600/22495 batches | lr 0.00014 | ms/batch 36.10 | loss  5.62 | ppl   276.61
# | epoch   5 |  3800/22495 batches | lr 0.00014 | ms/batch 36.16 | loss  5.69 | ppl   296.82
# | epoch   5 |  4000/22495 batches | lr 0.00014 | ms/batch 36.22 | loss  5.70 | ppl   297.86
# | epoch   5 |  4200/22495 batches | lr 0.00014 | ms/batch 36.43 | loss  5.71 | ppl   301.27
# | epoch   5 |  4400/22495 batches | lr 0.00014 | ms/batch 36.44 | loss  5.67 | ppl   289.44
# ...
# -----------------------------------------------------------------------------------------
# | end of iteration 480000 | valid loss  5.85 | valid ppl   346.19
# -----------------------------------------------------------------------------------------
# | epoch  22 |  7800/22495 batches | lr 0.00006 | ms/batch 170.11 | loss  4.95 | ppl   140.99
# | epoch  22 |  8000/22495 batches | lr 0.00006 | ms/batch 37.47 | loss  4.91 | ppl   135.12
# | epoch  22 |  8200/22495 batches | lr 0.00006 | ms/batch 37.63 | loss  4.88 | ppl   131.82
# | epoch  22 |  8400/22495 batches | lr 0.00006 | ms/batch 37.45 | loss  4.93 | ppl   138.71
# | epoch  22 |  8600/22495 batches | lr 0.00006 | ms/batch 37.27 | loss  4.95 | ppl   141.02
# | epoch  22 |  8800/22495 batches | lr 0.00006 | ms/batch 37.06 | loss  4.91 | ppl   135.11
# | epoch  22 |  9000/22495 batches | lr 0.00006 | ms/batch 37.24 | loss  4.95 | ppl   140.76
# | epoch  22 |  9200/22495 batches | lr 0.00006 | ms/batch 37.42 | loss  4.97 | ppl   143.73
# | epoch  22 |  9400/22495 batches | lr 0.00006 | ms/batch 37.23 | loss  4.92 | ppl   137.00
# | epoch  22 |  9600/22495 batches | lr 0.00006 | ms/batch 37.36 | loss  4.93 | ppl   138.27
# | epoch  22 |  9800/22495 batches | lr 0.00006 | ms/batch 37.30 | loss  4.90 | ppl   134.17
# | epoch  22 | 10000/22495 batches | lr 0.00006 | ms/batch 37.27 | loss  4.92 | ppl   136.78
# | epoch  22 | 10200/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.88 | ppl   131.72
# | epoch  22 | 10400/22495 batches | lr 0.00006 | ms/batch 37.37 | loss  4.89 | ppl   132.96
# | epoch  22 | 10600/22495 batches | lr 0.00006 | ms/batch 37.44 | loss  4.96 | ppl   142.95
# | epoch  22 | 10800/22495 batches | lr 0.00006 | ms/batch 37.29 | loss  4.87 | ppl   130.05
# | epoch  22 | 11000/22495 batches | lr 0.00006 | ms/batch 37.51 | loss  4.91 | ppl   135.50
# | epoch  22 | 11200/22495 batches | lr 0.00006 | ms/batch 37.45 | loss  4.92 | ppl   137.35
# | epoch  22 | 11400/22495 batches | lr 0.00006 | ms/batch 37.36 | loss  4.92 | ppl   136.54
# | epoch  22 | 11600/22495 batches | lr 0.00006 | ms/batch 37.27 | loss  4.93 | ppl   139.05
# | epoch  22 | 11800/22495 batches | lr 0.00006 | ms/batch 37.22 | loss  4.92 | ppl   137.51
# | epoch  22 | 12000/22495 batches | lr 0.00006 | ms/batch 37.38 | loss  4.91 | ppl   136.01
# | epoch  22 | 12200/22495 batches | lr 0.00006 | ms/batch 37.35 | loss  4.94 | ppl   140.27
# | epoch  22 | 12400/22495 batches | lr 0.00006 | ms/batch 37.54 | loss  4.94 | ppl   139.08
# | epoch  22 | 12600/22495 batches | lr 0.00006 | ms/batch 37.64 | loss  4.94 | ppl   139.38
# -----------------------------------------------------------------------------------------
# | end of iteration 485000 | valid loss  5.85 | valid ppl   347.87
# -----------------------------------------------------------------------------------------
# | epoch  22 | 12800/22495 batches | lr 0.00006 | ms/batch 173.45 | loss  4.91 | ppl   135.74
# | epoch  22 | 13000/22495 batches | lr 0.00006 | ms/batch 37.60 | loss  4.92 | ppl   137.66
# | epoch  22 | 13200/22495 batches | lr 0.00006 | ms/batch 37.74 | loss  4.91 | ppl   135.18
# | epoch  22 | 13400/22495 batches | lr 0.00006 | ms/batch 37.30 | loss  4.91 | ppl   135.77
# | epoch  22 | 13600/22495 batches | lr 0.00006 | ms/batch 37.72 | loss  4.96 | ppl   142.19
# | epoch  22 | 13800/22495 batches | lr 0.00006 | ms/batch 37.74 | loss  4.93 | ppl   138.23
# | epoch  22 | 14000/22495 batches | lr 0.00006 | ms/batch 37.69 | loss  4.96 | ppl   142.99
# | epoch  22 | 14200/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.95 | ppl   141.68
# | epoch  22 | 14400/22495 batches | lr 0.00006 | ms/batch 37.43 | loss  4.90 | ppl   133.74
# | epoch  22 | 14600/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.92 | ppl   137.37
# | epoch  22 | 14800/22495 batches | lr 0.00006 | ms/batch 37.52 | loss  4.92 | ppl   136.89
# | epoch  22 | 15000/22495 batches | lr 0.00006 | ms/batch 37.26 | loss  4.92 | ppl   136.98
# | epoch  22 | 15200/22495 batches | lr 0.00006 | ms/batch 37.63 | loss  4.95 | ppl   141.67
# | epoch  22 | 15400/22495 batches | lr 0.00006 | ms/batch 37.40 | loss  4.95 | ppl   141.44
# | epoch  22 | 15600/22495 batches | lr 0.00006 | ms/batch 37.60 | loss  4.92 | ppl   136.98
# | epoch  22 | 15800/22495 batches | lr 0.00006 | ms/batch 37.33 | loss  4.93 | ppl   137.71
# | epoch  22 | 16000/22495 batches | lr 0.00006 | ms/batch 37.51 | loss  4.95 | ppl   140.55
# | epoch  22 | 16200/22495 batches | lr 0.00006 | ms/batch 37.38 | loss  4.91 | ppl   136.25
# | epoch  22 | 16400/22495 batches | lr 0.00006 | ms/batch 37.64 | loss  4.88 | ppl   131.70
# | epoch  22 | 16600/22495 batches | lr 0.00006 | ms/batch 37.41 | loss  4.94 | ppl   139.69
# | epoch  22 | 16800/22495 batches | lr 0.00006 | ms/batch 37.49 | loss  4.90 | ppl   134.83
# | epoch  22 | 17000/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.90 | ppl   134.95
# | epoch  22 | 17200/22495 batches | lr 0.00006 | ms/batch 37.62 | loss  4.92 | ppl   137.54
# | epoch  22 | 17400/22495 batches | lr 0.00006 | ms/batch 37.43 | loss  4.91 | ppl   135.82
# | epoch  22 | 17600/22495 batches | lr 0.00006 | ms/batch 37.56 | loss  4.92 | ppl   136.65
# -----------------------------------------------------------------------------------------
# | end of iteration 490000 | valid loss  5.85 | valid ppl   348.43
# -----------------------------------------------------------------------------------------
# | epoch  22 | 17800/22495 batches | lr 0.00006 | ms/batch 173.51 | loss  4.90 | ppl   134.15
# | epoch  22 | 18000/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.89 | ppl   132.61
# | epoch  22 | 18200/22495 batches | lr 0.00006 | ms/batch 37.56 | loss  4.89 | ppl   132.48
# | epoch  22 | 18400/22495 batches | lr 0.00006 | ms/batch 37.66 | loss  4.97 | ppl   143.63
# | epoch  22 | 18600/22495 batches | lr 0.00006 | ms/batch 37.62 | loss  4.89 | ppl   132.36
# | epoch  22 | 18800/22495 batches | lr 0.00006 | ms/batch 37.35 | loss  4.87 | ppl   129.93
# | epoch  22 | 19000/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.91 | ppl   135.26
# | epoch  22 | 19200/22495 batches | lr 0.00006 | ms/batch 37.81 | loss  4.86 | ppl   128.93
# | epoch  22 | 19400/22495 batches | lr 0.00006 | ms/batch 37.52 | loss  4.93 | ppl   138.80
# | epoch  22 | 19600/22495 batches | lr 0.00006 | ms/batch 37.67 | loss  4.92 | ppl   136.69
# | epoch  22 | 19800/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.93 | ppl   138.88
# | epoch  22 | 20000/22495 batches | lr 0.00006 | ms/batch 37.60 | loss  4.88 | ppl   132.10
# | epoch  22 | 20200/22495 batches | lr 0.00006 | ms/batch 37.57 | loss  4.91 | ppl   135.57
# | epoch  22 | 20400/22495 batches | lr 0.00006 | ms/batch 37.54 | loss  4.97 | ppl   144.35
# | epoch  22 | 20600/22495 batches | lr 0.00006 | ms/batch 37.85 | loss  4.93 | ppl   137.94
# | epoch  22 | 20800/22495 batches | lr 0.00006 | ms/batch 38.19 | loss  4.89 | ppl   132.97
# | epoch  22 | 21000/22495 batches | lr 0.00006 | ms/batch 38.17 | loss  4.91 | ppl   135.03
# | epoch  22 | 21200/22495 batches | lr 0.00006 | ms/batch 37.72 | loss  4.91 | ppl   136.09
# | epoch  22 | 21400/22495 batches | lr 0.00006 | ms/batch 37.96 | loss  4.91 | ppl   136.26
# | epoch  22 | 21600/22495 batches | lr 0.00006 | ms/batch 37.78 | loss  4.90 | ppl   134.91
# | epoch  22 | 21800/22495 batches | lr 0.00006 | ms/batch 37.93 | loss  4.88 | ppl   131.96
# | epoch  22 | 22000/22495 batches | lr 0.00006 | ms/batch 38.08 | loss  4.91 | ppl   135.11
# | epoch  22 | 22200/22495 batches | lr 0.00006 | ms/batch 37.83 | loss  4.88 | ppl   132.10
# | epoch  22 | 22400/22495 batches | lr 0.00006 | ms/batch 37.82 | loss  4.91 | ppl   135.62
# -----------------------------------------------------------------------------------------
# | end of iteration 495000 | valid loss  5.88 | valid ppl   357.85
# -----------------------------------------------------------------------------------------
# | epoch  23 |   200/22495 batches | lr 0.00006 | ms/batch 172.76 | loss  4.94 | ppl   139.47
# | epoch  23 |   400/22495 batches | lr 0.00006 | ms/batch 37.75 | loss  4.89 | ppl   133.46
# | epoch  23 |   600/22495 batches | lr 0.00006 | ms/batch 37.56 | loss  4.92 | ppl   137.26
# | epoch  23 |   800/22495 batches | lr 0.00006 | ms/batch 37.74 | loss  4.90 | ppl   134.32
# | epoch  23 |  1000/22495 batches | lr 0.00006 | ms/batch 37.76 | loss  4.93 | ppl   137.85
# | epoch  23 |  1200/22495 batches | lr 0.00006 | ms/batch 37.75 | loss  4.91 | ppl   136.01
# | epoch  23 |  1400/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.92 | ppl   136.65
# | epoch  23 |  1600/22495 batches | lr 0.00006 | ms/batch 37.55 | loss  4.93 | ppl   137.88
# | epoch  23 |  1800/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.89 | ppl   133.28
# | epoch  23 |  2000/22495 batches | lr 0.00006 | ms/batch 37.61 | loss  4.89 | ppl   133.11
# | epoch  23 |  2200/22495 batches | lr 0.00006 | ms/batch 37.85 | loss  4.93 | ppl   138.04
# | epoch  23 |  2400/22495 batches | lr 0.00006 | ms/batch 37.88 | loss  4.90 | ppl   134.62
# | epoch  23 |  2600/22495 batches | lr 0.00006 | ms/batch 37.43 | loss  4.91 | ppl   136.13
# | epoch  23 |  2800/22495 batches | lr 0.00006 | ms/batch 37.64 | loss  4.87 | ppl   130.67
# | epoch  23 |  3000/22495 batches | lr 0.00006 | ms/batch 37.65 | loss  4.91 | ppl   135.28
# | epoch  23 |  3200/22495 batches | lr 0.00006 | ms/batch 37.82 | loss  4.87 | ppl   130.92
# | epoch  23 |  3400/22495 batches | lr 0.00006 | ms/batch 37.70 | loss  4.88 | ppl   131.51
# | epoch  23 |  3600/22495 batches | lr 0.00006 | ms/batch 37.42 | loss  4.86 | ppl   128.58
# | epoch  23 |  3800/22495 batches | lr 0.00006 | ms/batch 37.83 | loss  4.92 | ppl   137.59
# | epoch  23 |  4000/22495 batches | lr 0.00006 | ms/batch 38.00 | loss  4.89 | ppl   133.56
# | epoch  23 |  4200/22495 batches | lr 0.00006 | ms/batch 37.38 | loss  4.91 | ppl   135.58
# | epoch  23 |  4400/22495 batches | lr 0.00006 | ms/batch 37.59 | loss  4.90 | ppl   134.11
# | epoch  23 |  4600/22495 batches | lr 0.00006 | ms/batch 37.58 | loss  4.94 | ppl   140.05
# | epoch  23 |  4800/22495 batches | lr 0.00006 | ms/batch 37.65 | loss  4.88 | ppl   132.04
# | epoch  23 |  5000/22495 batches | lr 0.00006 | ms/batch 37.42 | loss  4.87 | ppl   130.00
# -----------------------------------------------------------------------------------------
# | end of iteration 500000 | valid loss  5.87 | valid ppl   355.43
# -----------------------------------------------------------------------------------------
# | epoch  23 |  5200/22495 batches | lr 0.00006 | ms/batch 172.36 | loss  4.86 | ppl   128.50
# | epoch  23 |  5400/22495 batches | lr 0.00006 | ms/batch 37.31 | loss  4.86 | ppl   129.25
# | epoch  23 |  5600/22495 batches | lr 0.00006 | ms/batch 37.47 | loss  4.89 | ppl   132.50
# | epoch  23 |  5800/22495 batches | lr 0.00006 | ms/batch 37.59 | loss  4.85 | ppl   127.36
# | epoch  23 |  6000/22495 batches | lr 0.00006 | ms/batch 37.52 | loss  4.85 | ppl   127.56
# | epoch  23 |  6200/22495 batches | lr 0.00006 | ms/batch 37.48 | loss  4.88 | ppl   131.04
# | epoch  23 |  6400/22495 batches | lr 0.00006 | ms/batch 37.60 | loss  4.88 | ppl   131.42
# | epoch  23 |  6600/22495 batches | lr 0.00006 | ms/batch 37.71 | loss  4.94 | ppl   139.32
# | epoch  23 |  6800/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.86 | ppl   129.50
# | epoch  23 |  7000/22495 batches | lr 0.00006 | ms/batch 37.35 | loss  4.88 | ppl   131.38
# | epoch  23 |  7200/22495 batches | lr 0.00006 | ms/batch 37.53 | loss  4.90 | ppl   134.45
# | epoch  23 |  7400/22495 batches | lr 0.00006 | ms/batch 37.31 | loss  4.91 | ppl   135.54
# | epoch  23 |  7600/22495 batches | lr 0.00006 | ms/batch 37.74 | loss  4.89 | ppl   132.75
# | epoch  23 |  7800/22495 batches | lr 0.00006 | ms/batch 37.33 | loss  4.92 | ppl   136.89
# | epoch  23 |  8000/22495 batches | lr 0.00006 | ms/batch 37.40 | loss  4.87 | ppl   130.68
# | epoch  23 |  8200/22495 batches | lr 0.00006 | ms/batch 37.70 | loss  4.85 | ppl   127.80
# | epoch  23 |  8400/22495 batches | lr 0.00006 | ms/batch 37.72 | loss  4.91 | ppl   135.48
# | epoch  23 |  8600/22495 batches | lr 0.00006 | ms/batch 37.51 | loss  4.92 | ppl   137.45
# | epoch  23 |  8800/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.88 | ppl   132.13
# | epoch  23 |  9000/22495 batches | lr 0.00006 | ms/batch 37.42 | loss  4.92 | ppl   136.93
# | epoch  23 |  9200/22495 batches | lr 0.00006 | ms/batch 37.52 | loss  4.94 | ppl   139.90
# | epoch  23 |  9400/22495 batches | lr 0.00006 | ms/batch 37.44 | loss  4.88 | ppl   131.03
# | epoch  23 |  9600/22495 batches | lr 0.00006 | ms/batch 37.43 | loss  4.90 | ppl   134.83
# | epoch  23 |  9800/22495 batches | lr 0.00006 | ms/batch 37.52 | loss  4.85 | ppl   127.25
# | epoch  23 | 10000/22495 batches | lr 0.00006 | ms/batch 37.41 | loss  4.87 | ppl   130.76
# -----------------------------------------------------------------------------------------
# | end of iteration 505000 | valid loss  5.86 | valid ppl   350.50
# -----------------------------------------------------------------------------------------
# | epoch  23 | 10200/22495 batches | lr 0.00006 | ms/batch 170.38 | loss  4.85 | ppl   128.30
# | epoch  23 | 10400/22495 batches | lr 0.00006 | ms/batch 37.85 | loss  4.85 | ppl   128.21
# | epoch  23 | 10600/22495 batches | lr 0.00006 | ms/batch 37.63 | loss  4.93 | ppl   138.77
# | epoch  23 | 10800/22495 batches | lr 0.00006 | ms/batch 37.25 | loss  4.83 | ppl   124.89
# | epoch  23 | 11000/22495 batches | lr 0.00006 | ms/batch 37.58 | loss  4.86 | ppl   129.15
# | epoch  23 | 11200/22495 batches | lr 0.00006 | ms/batch 37.56 | loss  4.89 | ppl   132.72
# | epoch  23 | 11400/22495 batches | lr 0.00006 | ms/batch 37.40 | loss  4.88 | ppl   131.24
# | epoch  23 | 11600/22495 batches | lr 0.00006 | ms/batch 37.37 | loss  4.89 | ppl   132.78
# | epoch  23 | 11800/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.90 | ppl   133.88
# | epoch  23 | 12000/22495 batches | lr 0.00006 | ms/batch 37.52 | loss  4.89 | ppl   132.55
# | epoch  23 | 12200/22495 batches | lr 0.00006 | ms/batch 37.73 | loss  4.90 | ppl   134.85
# | epoch  23 | 12400/22495 batches | lr 0.00006 | ms/batch 37.66 | loss  4.89 | ppl   133.58
# | epoch  23 | 12600/22495 batches | lr 0.00006 | ms/batch 37.75 | loss  4.90 | ppl   133.63
# | epoch  23 | 12800/22495 batches | lr 0.00006 | ms/batch 37.30 | loss  4.86 | ppl   129.32
# | epoch  23 | 13000/22495 batches | lr 0.00006 | ms/batch 37.61 | loss  4.88 | ppl   132.07
# | epoch  23 | 13200/22495 batches | lr 0.00006 | ms/batch 37.26 | loss  4.88 | ppl   131.68
# | epoch  23 | 13400/22495 batches | lr 0.00006 | ms/batch 37.43 | loss  4.87 | ppl   130.44
# | epoch  23 | 13600/22495 batches | lr 0.00006 | ms/batch 37.50 | loss  4.90 | ppl   134.94
# | epoch  23 | 13800/22495 batches | lr 0.00006 | ms/batch 37.70 | loss  4.90 | ppl   134.20
# | epoch  23 | 14000/22495 batches | lr 0.00006 | ms/batch 37.35 | loss  4.92 | ppl   137.59
# | epoch  23 | 14200/22495 batches | lr 0.00006 | ms/batch 37.47 | loss  4.92 | ppl   136.47
# | epoch  23 | 14400/22495 batches | lr 0.00006 | ms/batch 37.39 | loss  4.85 | ppl   127.74
# | epoch  23 | 14600/22495 batches | lr 0.00006 | ms/batch 37.62 | loss  4.87 | ppl   130.78
# | epoch  23 | 14800/22495 batches | lr 0.00006 | ms/batch 37.69 | loss  4.88 | ppl   132.15
# | epoch  23 | 15000/22495 batches | lr 0.00006 | ms/batch 37.33 | loss  4.89 | ppl   132.90
# -----------------------------------------------------------------------------------------
# | end of iteration 510000 | valid loss  5.87 | valid ppl   354.61
# -----------------------------------------------------------------------------------------
# | epoch  23 | 15200/22495 batches | lr 0.00006 | ms/batch 170.26 | loss  4.91 | ppl   135.37
# | epoch  23 | 15400/22495 batches | lr 0.00006 | ms/batch 37.41 | loss  4.91 | ppl   135.74
# | epoch  23 | 15600/22495 batches | lr 0.00006 | ms/batch 37.28 | loss  4.89 | ppl   132.76
# | epoch  23 | 15800/22495 batches | lr 0.00006 | ms/batch 37.55 | loss  4.90 | ppl   133.63
# | epoch  23 | 16000/22495 batches | lr 0.00006 | ms/batch 37.55 | loss  4.90 | ppl   133.84
# | epoch  23 | 16200/22495 batches | lr 0.00006 | ms/batch 37.54 | loss  4.88 | ppl   132.09

# %%
# Load the best saved model.
with open(args.save, 'rb') as f:
    model = torch.load(f)
    # after load the rnn params are not a continuous chunk of memory
    # this makes them a continuous chunk, and will speed up forward pass
    # Currently, only rnn model supports flatten_parameters function.
    if args.model in ['RNN_TANH', 'RNN_RELU', 'LSTM', 'GRU']:
        model.rnn.flatten_parameters()

# %%
# Run on test data.
test_loss = evaluate(test_data, 1)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
